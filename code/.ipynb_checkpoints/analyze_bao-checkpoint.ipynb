# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import string
from collections import defaultdict

# %%
plt.rcParams["font.size"] = 16

# %%
with open("Bao_runs/pg_run.txt") as f:
    data = f.read().split("\n")[2:]
data = [x.split(" ") for x in data if len(x) > 1 and (x[0] in string.digits or x[0] == "x")]

data = [(x[0], x[1], float(x[2]), x[3], float(x[4])) for x in data]
pg_data = data
pg_times = np.array([x[2] for x in pg_data])
pg_times -= np.min(pg_times)
pg_times /= 60

def read_bao_gs_data(fp):
    with open(fp) as f:
        data = f.read().split("\n")[2:]

    training_times = []
    for idx in range(len(data)):
        if data[idx].strip().startswith("Start training"):
            prev_line = data[idx-1].split(" ")
            if prev_line[0] != "x" and prev_line[0][0] not in string.digits:
                continue
            if prev_line[0] == "Retry":
                continue
            training_times.append(float(prev_line[2]))


    training_times = np.array(training_times)

    data = [x.split(" ") for x in data if len(x) > 1 and (x[0] in string.digits or x[0] == "x")]
    data = [(x[0], x[1], float(x[2]), x[3], float(x[4])) for x in data]
    bao_data = data

    bao_times = np.array([x[2] for x in bao_data])
    training_times -= np.min(bao_times)
    bao_times -= np.min(bao_times)

    bao_times /= 60
    training_times /= 60
    return bao_data, bao_times, training_times


def read_bao_data(fp):
    with open(fp) as f:
        data = f.read().split("\n")[2:]

    training_times = []
    for idx in range(len(data)):
        if data[idx].strip().startswith("Initial input channels"):
            prev_line = data[idx-1].split(" ")
            if prev_line[0] == "Retry":
                continue
            training_times.append(float(prev_line[2]))


    training_times = np.array(training_times)

    data = [x.split(" ") for x in data if len(x) > 1 and (x[0] in string.digits or x[0] == "x")]
    data = [(x[0], x[1], float(x[2]), x[3], float(x[4])) for x in data]
    bao_data = data

    bao_times = np.array([x[2] for x in bao_data])
    training_times -= np.min(bao_times)
    bao_times -= np.min(bao_times)

    bao_times /= 60
    training_times /= 60
    return bao_data, bao_times, training_times

bao_data, bao_times, training_times = read_bao_data("Bao_runs/bao_run.txt")
bao_gs_data, bao_gs_times, gs_training_times = read_bao_gs_data("Bao_runs/bao_run_gs.txt")
bayes_data, bayes_times, bayes_training_times = read_bao_data("Bao_runs/bayes_run_log_uniform.txt")
bayes_norm_data, bayes_norm_times, bayes_norm_training_times = read_bao_data("Bao_runs/bayes_run_norm.txt")

# %%
queries_complete = np.arange(0, len(pg_times))

fig, ax = plt.subplots(1, 1, figsize=(15, 12), constrained_layout=True)

train_y = []
for tt in training_times:
    idx = np.searchsorted(bao_times, tt)
    train_y.append(idx)
    
plt.scatter(training_times, train_y, s=45, color="red", label="Training")
plt.scatter(gs_training_times, train_y, s=45, color="red", label="Training (grid search)")
plt.scatter(bayes_training_times, train_y, s=45, color="purple", label="Training (bayes log uniform)")
plt.scatter(bayes_norm_training_times, train_y, s=45, color="yellow", label="Training (bayes norm)")

ax.plot(pg_times, queries_complete, label="PostgreSQL", lw=3)
ax.plot(bao_times, queries_complete, label="Bao", lw=3)
ax.plot(bao_gs_times, queries_complete, label="Bao (grid search)", lw=3)
ax.plot(bayes_times, queries_complete, label="Bao (bayes log uniform)", lw=3)
ax.plot(bayes_norm_times, queries_complete, label="Bao (bayes norm)", lw=3)

ax.set_xlabel("Time (m)")
ax.set_ylabel("Queries complete")
ax.set_title("PostgreSQL vs Bao Optimizer")

ax.grid(linestyle="--", linewidth=1)
ax.legend()
fig.savefig("queries_vs_time.svg")

# %%
all_pg_times = sorted([x[4] for x in pg_data])
all_bao_times = sorted([x[4] for x in bao_data])
all_bao_gs_times = sorted([x[4] for x in bao_gs_data])
all_bayes_times = sorted([x[4] for x in bayes_data])
all_bayes_norm_times = sorted([x[4] for x in bayes_norm_data])

fig, axes = plt.subplots(2, 1, figsize=(15, 20), constrained_layout=True)

ax = axes[0]
ax.plot(np.linspace(0, 1, len(all_bayes_times)), all_pg_times, lw=3, label="PostgreSQL")
ax.plot(np.linspace(0, 1, len(all_bayes_times)), all_bao_times, lw=3, label="Bao")
ax.plot(np.linspace(0, 1, len(all_bayes_times)), all_bao_gs_times, lw=3, label="PostgreSQL")
ax.plot(np.linspace(0, 1, len(all_bayes_times)), all_bayes_times, lw=3, label="Bao")
ax.plot(np.linspace(0, 1, len(all_bayes_times)), all_bayes_norm_times, lw=3, label="PostgreSQL")

ax.grid(linestyle="--", linewidth=1)
ax.set_xlabel("Proportion of Queries")
ax.set_ylabel("Max Latency (s)")
ax.set_title("Query Latency CDF")
ax.legend()

ax = axes[1]
ax.plot(np.linspace(0, 1, len(all_bayes_times)), all_pg_times, lw=3, label="PostgreSQL")
ax.plot(np.linspace(0, 1, len(all_bayes_times)), all_bao_times, lw=3, label="Bao")
ax.plot(np.linspace(0, 1, len(all_bayes_times)), all_bao_gs_times, lw=3, label="PostgreSQL")
ax.plot(np.linspace(0, 1, len(all_bayes_times)), all_bayes_times, lw=3, label="Bao")
ax.plot(np.linspace(0, 1, len(all_bayes_times)), all_bayes_norm_times, lw=3, label="PostgreSQL")

ax.grid(linestyle="--", linewidth=1)
ax.set_xlabel("Proportion of Queries")
ax.set_ylabel("Max Latency (s)")
ax.set_title("Query Latency CDF (log scale)")
ax.legend()
ax.set_yscale("log")
fig.savefig("cdf.svg")

# %%
# get the Average PG time for each query
pg_query_time = {}
pg_query_cnt = {}
for itm in pg_data:
    if itm[3] not in pg_query_time:
        pg_query_time[itm[3]] = 0
        pg_query_cnt[itm[3]] = 0
    pg_query_time[itm[3]] += itm[4]
    pg_query_cnt[itm[3]] += 1

for name, _ in pg_query_time.items():
    pg_query_time[name] /= pg_query_cnt[name]

# Get other query times from the 50 query
bao_query_times = defaultdict(list)
for itm in bao_data[50:]:
    bao_query_times[itm[3]].append(itm[4])

bao_gs_query_times = defaultdict(list)
for itm in bao_gs_data[50:]:
    bao_gs_query_times[itm[3]].append(itm[4])

bayes_query_times = defaultdict(list)
for itm in bayes_data[50:]:
    bayes_query_times[itm[3]].append(itm[4])

bayes_norm_query_times = defaultdict(list)
for itm in bayes_norm_data[50:]:
    bayes_norm_query_times[itm[3]].append(itm[4])

max_repeats = max(len(x) for x in bao_query_times.values())

def extract_q_number(x):
    return int(x[x.find("/q")+2:x.find("_", x.find("/q"))])

q_order = sorted(bao_query_times.keys(), key=extract_q_number)

grid_bao = [bao_query_times[x] for x in q_order]
grid_bao_gs = [bao_gs_query_times[x] for x in q_order]
grid_bayes = [bayes_query_times[x] for x in q_order]
grid_bayes_norm = [bayes_norm_query_times[x] for x in q_order]

reg_data = []
for idx, q in enumerate(q_order):
    reg_data.append({"Q": f"q{extract_q_number(q)}", 
                     "PG": pg_query_time[q],
                     "Bao worst": max(grid_bao[idx]),
                     "Bao best": min(grid_bao[idx]),
                     "Bao (grid search) worst": max(grid_bao_gs[idx]),
                     "Bao (grid_search) best": min(grid_bao_gs[idx]),
                     "Bao (bayes log uniform) worst": max(grid_bayes[idx]),
                     "Bao (bayes log uniform) best": min(grid_bayes[idx]),
                     "Bao (bayes norm) worst": max(grid_bayes_norm[idx]),
                     "Bao (bayes norm) best": min(grid_bayes_norm[idx]),
                    })
                


def color_regression(col):
    def c_for_diff(diff):
        if diff < -2:
            return "background-color: #9ee3ad"
        elif diff > 2:
            return "background-color: #f27281"
        elif diff > 0:
            return "background-color: yellow"
        else:
            return "background-color: white"
            
        
    to_r = [""]
    
    pg, bao_worst, bao_best, bao_gs_worst, bao_gs_best, bayes_worst, bayes_best, bayes_norm_worst, bayes_norm_best = col

    
    to_r.append(c_for_diff(bao_worst - pg))
    to_r.append(c_for_diff(bao_best - pg))
    to_r.append(c_for_diff(bao_gs_worst - pg))
    to_r.append(c_for_diff(bao_gs_best - pg))
    to_r.append(c_for_diff(bayes_worst - pg))
    to_r.append(c_for_diff(bayes_best - pg))
    to_r.append(c_for_diff(bayes_norm_worst - pg))
    to_r.append(c_for_diff(bayes_norm_best - pg))

    return to_r

reg_data = pd.DataFrame(reg_data).set_index("Q")
reg_data.style.apply(color_regression, axis=1)
# Out:
# <style type="text/css">
# #T_76928_row0_col1, #T_76928_row2_col4, #T_76928_row3_col2, #T_76928_row3_col4, #T_76928_row3_col8, #T_76928_row6_col3, #T_76928_row7_col7, #T_76928_row8_col1, #T_76928_row8_col7, #T_76928_row9_col2, #T_76928_row9_col8, #T_76928_row10_col7, #T_76928_row13_col2, #T_76928_row13_col3, #T_76928_row13_col4, #T_76928_row13_col6, #T_76928_row13_col7, #T_76928_row13_col8, #T_76928_row14_col1, #T_76928_row14_col2, #T_76928_row14_col3, #T_76928_row14_col4, #T_76928_row14_col5, #T_76928_row14_col6, #T_76928_row14_col7, #T_76928_row14_col8, #T_76928_row15_col1, #T_76928_row15_col2, #T_76928_row15_col3, #T_76928_row15_col4, #T_76928_row15_col6, #T_76928_row15_col8, #T_76928_row16_col1, #T_76928_row16_col2, #T_76928_row16_col3, #T_76928_row16_col4, #T_76928_row16_col6, #T_76928_row16_col7, #T_76928_row16_col8, #T_76928_row17_col1, #T_76928_row17_col7, #T_76928_row18_col2, #T_76928_row18_col4, #T_76928_row18_col6, #T_76928_row22_col2, #T_76928_row22_col4, #T_76928_row22_col6, #T_76928_row22_col8, #T_76928_row24_col4, #T_76928_row25_col1, #T_76928_row25_col2, #T_76928_row25_col4, #T_76928_row25_col6, #T_76928_row25_col7, #T_76928_row25_col8, #T_76928_row29_col1, #T_76928_row29_col2, #T_76928_row29_col3, #T_76928_row29_col4, #T_76928_row29_col5, #T_76928_row29_col6, #T_76928_row29_col7, #T_76928_row29_col8, #T_76928_row32_col6, #T_76928_row32_col8, #T_76928_row33_col4, #T_76928_row34_col1, #T_76928_row34_col2, #T_76928_row34_col3, #T_76928_row34_col4, #T_76928_row34_col6, #T_76928_row34_col8, #T_76928_row35_col2, #T_76928_row35_col4, #T_76928_row35_col6, #T_76928_row35_col8, #T_76928_row36_col2, #T_76928_row36_col4, #T_76928_row36_col6, #T_76928_row36_col8, #T_76928_row37_col4, #T_76928_row38_col4, #T_76928_row39_col2, #T_76928_row39_col4, #T_76928_row39_col6, #T_76928_row39_col8 {
#   background-color: white;
# }
# #T_76928_row0_col2, #T_76928_row0_col4, #T_76928_row0_col6, #T_76928_row0_col8, #T_76928_row1_col1, #T_76928_row1_col2, #T_76928_row1_col3, #T_76928_row1_col4, #T_76928_row1_col6, #T_76928_row1_col8, #T_76928_row4_col1, #T_76928_row4_col2, #T_76928_row4_col3, #T_76928_row4_col4, #T_76928_row4_col6, #T_76928_row4_col7, #T_76928_row4_col8, #T_76928_row5_col2, #T_76928_row5_col4, #T_76928_row5_col6, #T_76928_row5_col8, #T_76928_row6_col2, #T_76928_row6_col4, #T_76928_row6_col6, #T_76928_row6_col8, #T_76928_row7_col1, #T_76928_row7_col2, #T_76928_row7_col3, #T_76928_row7_col4, #T_76928_row7_col6, #T_76928_row7_col8, #T_76928_row8_col2, #T_76928_row8_col4, #T_76928_row8_col6, #T_76928_row8_col8, #T_76928_row9_col4, #T_76928_row9_col6, #T_76928_row10_col1, #T_76928_row10_col2, #T_76928_row10_col3, #T_76928_row10_col4, #T_76928_row10_col6, #T_76928_row10_col8, #T_76928_row11_col1, #T_76928_row11_col2, #T_76928_row11_col3, #T_76928_row11_col4, #T_76928_row11_col6, #T_76928_row11_col8, #T_76928_row17_col2, #T_76928_row17_col3, #T_76928_row17_col4, #T_76928_row17_col6, #T_76928_row17_col8, #T_76928_row21_col2, #T_76928_row21_col3, #T_76928_row21_col4, #T_76928_row21_col6, #T_76928_row21_col8 {
#   background-color: #9ee3ad;
# }
# #T_76928_row0_col3, #T_76928_row0_col7, #T_76928_row2_col1, #T_76928_row2_col2, #T_76928_row2_col3, #T_76928_row2_col6, #T_76928_row2_col8, #T_76928_row3_col1, #T_76928_row3_col3, #T_76928_row3_col6, #T_76928_row3_col7, #T_76928_row5_col1, #T_76928_row6_col5, #T_76928_row6_col7, #T_76928_row8_col3, #T_76928_row9_col1, #T_76928_row9_col3, #T_76928_row9_col7, #T_76928_row11_col7, #T_76928_row12_col2, #T_76928_row12_col3, #T_76928_row12_col4, #T_76928_row12_col6, #T_76928_row12_col8, #T_76928_row13_col1, #T_76928_row15_col7, #T_76928_row17_col5, #T_76928_row18_col8, #T_76928_row19_col1, #T_76928_row19_col2, #T_76928_row19_col3, #T_76928_row19_col4, #T_76928_row19_col5, #T_76928_row19_col6, #T_76928_row19_col7, #T_76928_row19_col8, #T_76928_row20_col2, #T_76928_row20_col4, #T_76928_row20_col5, #T_76928_row20_col6, #T_76928_row20_col8, #T_76928_row22_col1, #T_76928_row22_col3, #T_76928_row22_col7, #T_76928_row23_col1, #T_76928_row23_col2, #T_76928_row23_col3, #T_76928_row23_col4, #T_76928_row23_col5, #T_76928_row23_col6, #T_76928_row23_col7, #T_76928_row23_col8, #T_76928_row24_col1, #T_76928_row24_col2, #T_76928_row24_col3, #T_76928_row24_col5, #T_76928_row24_col6, #T_76928_row24_col7, #T_76928_row24_col8, #T_76928_row25_col3, #T_76928_row26_col1, #T_76928_row26_col2, #T_76928_row26_col3, #T_76928_row26_col4, #T_76928_row26_col5, #T_76928_row26_col6, #T_76928_row26_col7, #T_76928_row26_col8, #T_76928_row27_col1, #T_76928_row27_col2, #T_76928_row27_col3, #T_76928_row27_col4, #T_76928_row27_col5, #T_76928_row27_col6, #T_76928_row27_col7, #T_76928_row27_col8, #T_76928_row28_col1, #T_76928_row28_col2, #T_76928_row28_col3, #T_76928_row28_col4, #T_76928_row28_col5, #T_76928_row28_col6, #T_76928_row28_col7, #T_76928_row28_col8, #T_76928_row30_col1, #T_76928_row30_col2, #T_76928_row30_col3, #T_76928_row30_col4, #T_76928_row30_col6, #T_76928_row30_col7, #T_76928_row30_col8, #T_76928_row31_col3, #T_76928_row31_col4, #T_76928_row31_col6, #T_76928_row32_col1, #T_76928_row32_col2, #T_76928_row32_col3, #T_76928_row32_col4, #T_76928_row32_col7, #T_76928_row33_col1, #T_76928_row33_col2, #T_76928_row33_col6, #T_76928_row33_col7, #T_76928_row33_col8, #T_76928_row34_col7, #T_76928_row35_col1, #T_76928_row35_col3, #T_76928_row35_col5, #T_76928_row35_col7, #T_76928_row37_col2, #T_76928_row37_col6, #T_76928_row37_col8, #T_76928_row38_col2, #T_76928_row38_col3, #T_76928_row38_col6, #T_76928_row38_col8 {
#   background-color: yellow;
# }
# #T_76928_row0_col5, #T_76928_row1_col5, #T_76928_row1_col7, #T_76928_row2_col5, #T_76928_row2_col7, #T_76928_row3_col5, #T_76928_row4_col5, #T_76928_row5_col3, #T_76928_row5_col5, #T_76928_row5_col7, #T_76928_row6_col1, #T_76928_row7_col5, #T_76928_row8_col5, #T_76928_row9_col5, #T_76928_row10_col5, #T_76928_row11_col5, #T_76928_row12_col1, #T_76928_row12_col5, #T_76928_row12_col7, #T_76928_row13_col5, #T_76928_row15_col5, #T_76928_row16_col5, #T_76928_row18_col1, #T_76928_row18_col3, #T_76928_row18_col5, #T_76928_row18_col7, #T_76928_row20_col1, #T_76928_row20_col3, #T_76928_row20_col7, #T_76928_row21_col1, #T_76928_row21_col5, #T_76928_row21_col7, #T_76928_row22_col5, #T_76928_row25_col5, #T_76928_row30_col5, #T_76928_row31_col1, #T_76928_row31_col2, #T_76928_row31_col5, #T_76928_row31_col7, #T_76928_row31_col8, #T_76928_row32_col5, #T_76928_row33_col3, #T_76928_row33_col5, #T_76928_row34_col5, #T_76928_row36_col1, #T_76928_row36_col3, #T_76928_row36_col5, #T_76928_row36_col7, #T_76928_row37_col1, #T_76928_row37_col3, #T_76928_row37_col5, #T_76928_row37_col7, #T_76928_row38_col1, #T_76928_row38_col5, #T_76928_row38_col7, #T_76928_row39_col1, #T_76928_row39_col3, #T_76928_row39_col5, #T_76928_row39_col7 {
#   background-color: #f27281;
# }
# </style>
# <table id="T_76928">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76928_level0_col0" class="col_heading level0 col0" >PG</th>
#       <th id="T_76928_level0_col1" class="col_heading level0 col1" >Bao worst</th>
#       <th id="T_76928_level0_col2" class="col_heading level0 col2" >Bao best</th>
#       <th id="T_76928_level0_col3" class="col_heading level0 col3" >Bao (grid search) worst</th>
#       <th id="T_76928_level0_col4" class="col_heading level0 col4" >Bao (grid_search) best</th>
#       <th id="T_76928_level0_col5" class="col_heading level0 col5" >Bao (bayes log uniform) worst</th>
#       <th id="T_76928_level0_col6" class="col_heading level0 col6" >Bao (bayes log uniform) best</th>
#       <th id="T_76928_level0_col7" class="col_heading level0 col7" >Bao (bayes norm) worst</th>
#       <th id="T_76928_level0_col8" class="col_heading level0 col8" >Bao (bayes norm) best</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Q</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class
